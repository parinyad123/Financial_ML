# %% [markdown]
# # Feature description :
#
# There are 25 variables:
#
# - ID: ID of each client
# - LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# - SEX: Gender (1=male, 2=female)
# - EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# - MARRIAGE: Marital status (1=married, 2=single, 3=others)
# - AGE: Age in years
# - PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two - - months, ... 8=payment delay for eight months, 9=payment delay for nine months and above)
# - PAY_2: Repayment status in August, 2005 (scale same as above)
# - PAY_3: Repayment status in July, 2005 (scale same as above)
# - PAY_4: Repayment status in June, 2005 (scale same as above)
# - PAY_5: Repayment status in May, 2005 (scale same as above)
# - PAY_6: Repayment status in April, 2005 (scale same as above)
# - BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# - BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# - BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# - BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# - BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# - BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# - PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# - PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# - PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# - PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# - PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# - PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# - default.payment.next.month: Default payment (1=yes, 0=no) $\textbf{: positive class: default | nagetive class: pay}$

# %% [markdown]
# # 0. Data preparation

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/meauxt/credit-card-default/master/credit_cards_dataset.csv'
df = pd.read_csv(url, index_col="ID")

# %%
df.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1     20000.0    2          2         1   24      2      2     -1     -1
# 2    120000.0    2          2         2   26     -1      2      0      0
# 3     90000.0    2          2         2   34      0      0      0      0
# 4     50000.0    2          2         1   37      0      0      0      0
# 5     50000.0    1          2         1   57     -1      0     -1      0
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# 1      -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 2       0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 3       0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 4       0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 5       0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
# ...

# %%
df.info() # สรุปข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null float64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null float64
# BILL_AMT2                     30000 non-null float64
# BILL_AMT3                     30000 non-null float64
# BILL_AMT4                     30000 non-null float64
# BILL_AMT5                     30000 non-null float64
# ...

# %%
df.describe() # สรุปข้อมูลแบบสถิติ
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
df.rename(columns=lambda x: x.lower(), inplace=True)

# %%
# Base values: female, other_education, not_married
df['grad_school']=(df['education']==1).astype('int')
df['university']=(df['education']==2).astype('int')
df['high_school']=(df['education']==3).astype('int')
df.drop('education', axis=1, inplace=True)

df['male']=(df['sex']==1).astype('int')
df.drop('sex', axis=1, inplace=True)

df['married']=(df['marriage']==1).astype('int')
df.drop('marriage', axis=1, inplace=True)

pay_feature = ['pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6']
for p in pay_feature:
    df.loc[df[p]<=0, p]=0
    
df.rename(columns={'default payment next month':'df'}, inplace=True)

df.head()
# Out:
#     limit_bal  age  pay_0  pay_2  pay_3  pay_4  pay_5  pay_6  bill_amt1  \
# ID
# 1     20000.0   24      2      2      0      0      0      0     3913.0
# 2    120000.0   26      0      2      0      0      0      2     2682.0
# 3     90000.0   34      0      0      0      0      0      0    29239.0
# 4     50000.0   37      0      0      0      0      0      0    46990.0
# 5     50000.0   57      0      0      0      0      0      0     8617.0
#
#     bill_amt2  ...  pay_amt3  pay_amt4  pay_amt5  pay_amt6  \
# ID             ...
# 1      3102.0  ...       0.0       0.0       0.0       0.0
# 2      1725.0  ...    1000.0    1000.0       0.0    2000.0
# 3     14027.0  ...    1000.0    1000.0    1000.0    5000.0
# 4     48233.0  ...    1200.0    1100.0    1069.0    1000.0
# 5      5670.0  ...   10000.0    9000.0     689.0     679.0
#
#     default.payment.next.month  grad_school  university  high_school  male  \
# ID
# ...

# %% [markdown]
# # Building models using all features

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, precision_recall_curve
from sklearn.preprocessing import RobustScaler

# %%
target_name = 'default.payment.next.month'
X = df.drop('default.payment.next.month', axis=1)

# # robustscaler is used to set all the variables to the same scale, called rescale
robust_scaler = RobustScaler()
X = robust_scaler.fit_transform(X)
y = df[target_name]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=123, stratify=y)

# %%
def CMatrix(CM, labels=['pay','default']):
    data_frame = pd.DataFrame(data=CM, index=label, columns=labels)
    data_frame.index.name='TRUE'
    data_frame.loc['Total'] = data_frame.sum()
    data_frame['Total']=data_frame.sum(axis=1)
    return data_frame

# %% [markdown]
# # Preparing a DataFrame for model analysis

# %%
#  data frame for evaluation metrics
# preparing a small data frame to save all the metrics for our different models
metrics = pd.DataFrame(index=['accuracy', 'precision', 'recall'],
                      columns=['NULL', 'LogisticReg', 'ClassTress', 'NaiveBayes'])

metrics
# Out:
#           NULL LogisticReg ClassTress NaiveBayes
# accuracy   NaN         NaN        NaN        NaN
# precision  NaN         NaN        NaN        NaN
# recall     NaN         NaN        NaN        NaN

# %% [markdown]
# - $\textbf{Accuracy}$: the proportion of the number of predictions that are correct
# - $\textbf{Precision}$: the proportion of positive predictions that are actually correct
# - $\textbf{Recall}$: the proportion of positive observed values correctly predicted as such
#
# #### In this appication:
#
# - $\textbf{Accuracy}$: Overall how often the model predicts correctly and non-defaulters
# - $\textbf{Precision}$: When the model predicts $\textbf{defualt}$: how often is correct?
# - $\textbf{Recall}$: The proportion of $\textbf{actual dafalters}$: that the model will correctly predict as such
#
# #### Which metric should I use?
# - $\textbf{False Positive}$: A person who will pay predicted as defaulter
# - $\textbf{False Negative}$: A person who defualt predicted as payer
#
# #### False metric are worse => look for a beeter recall
#
# # The Null model: always predict the most common category

# %%
y_pred_test = np.repeat(y_train.value_counts().idxmax(), y_test.size)
metrics.loc['accuracy', 'NULL']=accuracy_score(y_pred=y_pred_test, y_true=y_test)
metrics.loc['precision', 'NULL']=precision_score(y_pred=y_pred_test, y_true=y_test)
metrics.loc['recall', 'NULL']=recall_score(y_pred=y_pred_test, y_true=y_test)

CM = confusion_matrix(y_pred=y_pred_test, y_true=y_test)
CMatrix(CM)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-169c12495ebe> in <module>
#       5
#       6 CM = confusion_matrix(y_pred=y_pred_test, y_true=y_test)
# ----> 7 CMatrix(CM)
#
# <ipython-input-19-c30eb316beb3> in CMatrix(CM, labels)
#       1 def CMatrix(CM, labels=['pay','default']):
# ----> 2     data_frame = pd.DataFrame(data=CM, index=label, columns=labels)
#       3     data_frame.index.name='TRUE'
#       4     data_frame.loc['Total'] = data_frame.sum()
#       5     data_frame['Total']=data_frame.sum(axis=1)
#
# NameError: name 'label' is not defined
